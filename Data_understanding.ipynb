# %%
import pandas as pd

# %%
fund_master = pd.read_csv("01_fund_master.csv")

nav_history = pd.read_csv("02_nav_history.csv")

aum_by_fund_house = pd.read_csv("03_aum_by_fund_house.csv")

monthly_sip_inflows = pd.read_csv("04_monthly_sip_inflows.csv")

category_inflows = pd.read_csv("05_category_inflows.csv")

industry_folio_count = pd.read_csv("06_industry_folio_count.csv")

scheme_performance = pd.read_csv("07_scheme_performance.csv")

investor_transactions = pd.read_csv("08_investor_transactions.csv")

portfolio_holdings = pd.read_csv("09_portfolio_holdings.csv")

benchmark_indices = pd.read_csv("10_benchmark_indices.csv")

# %%
print("========== FUND MASTER ==========")

print("Shape:")
print(fund_master.shape)

print("\nFirst 5 Rows:")
display(fund_master.head())

print("\nInformation:")
fund_master.info()

print("\nMissing Values:")
print(fund_master.isnull().sum())

print("\nDuplicate Rows:")
print(fund_master.duplicated().sum())

print("\nStatistical Summary:")
display(fund_master.describe(include="all"))

print("\nUnique Fund Houses:")
print(fund_master["fund_house"].unique())

print("\nUnique Categories:")
print(fund_master["category"].unique())

print("\nUnique Sub Categories:")
print(fund_master["sub_category"].unique())

print("\nUnique Risk Categories:")
print(fund_master["risk_category"].unique())
# Out:
# ========== FUND MASTER ==========
# Shape:
# (40, 15)
#
# First 5 Rows:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
# ...

# %%
print("========== NAV HISTORY ==========")

print("Shape:")
print(nav_history.shape)

print("\nFirst 5 Rows:")
display(nav_history.head())

print("\nInformation:")
nav_history.info()

print("\nMissing Values:")
print(nav_history.isnull().sum())

print("\nDuplicate Rows:")
print(nav_history.duplicated().sum())

print("\nStatistical Summary:")
display(nav_history.describe(include="all"))
# Out:
# ========== NAV HISTORY ==========
# Shape:
# (46000, 3)
#
# First 5 Rows:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692
# Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  object
#  2   nav        46000 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ MB
#
# Missing Values:
# amfi_code    0
# date         0
# nav          0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# Statistical Summary:
#             amfi_code        date           nav
# count    46000.000000       46000  46000.000000
# unique            NaN        1150           NaN
# ...

# %%
print("========== AUM BY FUND HOUSE ==========")

print("Shape:")
print(aum_by_fund_house.shape)

print("\nFirst 5 Rows:")
display(aum_by_fund_house.head())

print("\nInformation:")
aum_by_fund_house.info()

print("\nMissing Values:")
print(aum_by_fund_house.isnull().sum())

print("\nDuplicate Rows:")
print(aum_by_fund_house.duplicated().sum())

print("\nStatistical Summary:")
display(aum_by_fund_house.describe(include="all"))
# Out:
# ========== AUM BY FUND HOUSE ==========
# Shape:
# (90, 5)
#
# First 5 Rows:
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168
# Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            90 non-null     object
#  1   fund_house      90 non-null     object
#  2   aum_lakh_crore  90 non-null     float64
#  3   aum_crore       90 non-null     int64
#  4   num_schemes     90 non-null     int64
# ...

# %%
print("========== MONTHLY SIP INFLOWS ==========")

print("Shape:")
print(monthly_sip_inflows.shape)

print("\nFirst 5 Rows:")
display(monthly_sip_inflows.head())

print("\nInformation:")
monthly_sip_inflows.info()

print("\nMissing Values:")
print(monthly_sip_inflows.isnull().sum())

print("\nDuplicate Rows:")
print(monthly_sip_inflows.duplicated().sum())

print("\nStatistical Summary:")
display(monthly_sip_inflows.describe(include="all"))
# Out:
# ========== MONTHLY SIP INFLOWS ==========
# Shape:
# (48, 6)
#
# First 5 Rows:
#      month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01             11517                       4.91
# 1  2022-02             11438                       4.93
# 2  2022-03             12328                       5.09
# 3  2022-04             11863                       5.48
# 4  2022-05             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# 3                   9.52                5.12             NaN
# 4                   8.10                5.15             NaN
# Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ...

# %%
print("========== CATEGORY INFLOWS ==========")

print("Shape:")
print(category_inflows.shape)

print("\nFirst 5 Rows:")
display(category_inflows.head())

print("\nInformation:")
category_inflows.info()

print("\nMissing Values:")
print(category_inflows.isnull().sum())

print("\nDuplicate Rows:")
print(category_inflows.duplicated().sum())

print("\nStatistical Summary:")
display(category_inflows.describe(include="all"))
# Out:
# ========== CATEGORY INFLOWS ==========
# Shape:
# (144, 3)
#
# First 5 Rows:
#      month         category  net_inflow_crore
# 0  2024-04        Large Cap            2413.0
# 1  2024-04          Mid Cap            3897.0
# 2  2024-04        Small Cap            3533.0
# 3  2024-04        Flexi Cap            4947.0
# 4  2024-04  Large & Mid Cap            4214.0
# Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month             144 non-null    object
#  1   category          144 non-null    object
#  2   net_inflow_crore  144 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 3.5+ KB
#
# Missing Values:
# month               0
# category            0
# net_inflow_crore    0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# Statistical Summary:
#           month   category  net_inflow_crore
# ...

# %%
print("========== INDUSTRY FOLIO COUNT ==========")

print("Shape:")
print(industry_folio_count.shape)

print("\nFirst 5 Rows:")
display(industry_folio_count.head())

print("\nInformation:")
industry_folio_count.info()

print("\nMissing Values:")
print(industry_folio_count.isnull().sum())

print("\nDuplicate Rows:")
print(industry_folio_count.duplicated().sum())

print("\nStatistical Summary:")
display(industry_folio_count.describe(include="all"))
# Out:
# ========== INDUSTRY FOLIO COUNT ==========
# Shape:
# (21, 6)
#
# First 5 Rows:
#      month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0  2022-01               13.26                 9.28               1.86
# 1  2022-04               13.91                 9.74               1.95
# 2  2022-07               13.85                 9.69               1.94
# 3  2022-10               14.12                 9.88               1.98
# 4  2023-01               14.81                10.37               2.07
#
#    hybrid_folios_crore  others_folios_crore
# 0                 0.80                 1.33
# 1                 0.83                 1.39
# 2                 0.83                 1.38
# 3                 0.85                 1.41
# 4                 0.89                 1.48
# Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ...

# %%
print("========== SCHEME PERFORMANCE ==========")

print("Shape:")
print(scheme_performance.shape)

print("\nFirst 5 Rows:")
display(scheme_performance.head())

print("\nInformation:")
scheme_performance.info()

print("\nMissing Values:")
print(scheme_performance.isnull().sum())

print("\nDuplicate Rows:")
print(scheme_performance.duplicated().sum())

print("\nStatistical Summary:")
display(scheme_performance.describe(include="all"))
# Out:
# ========== SCHEME PERFORMANCE ==========
# Shape:
# (40, 19)
#
# First 5 Rows:
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth  SBI Mutual Fund
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth  SBI Mutual Fund
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth  SBI Mutual Fund
#
#     category     plan  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0  Large Cap  Regular           12.42           12.36           14.45
# 1  Large Cap   Direct           15.25           11.30           14.23
# 2  Small Cap  Regular           24.56           23.39           20.67
# 3  Small Cap   Direct           20.59           23.14           21.82
# 4       Gilt  Regular            5.34            6.07            5.43
#
# ...

# %%
print("========== INVESTOR TRANSACTIONS ==========")

print("Shape:")
print(investor_transactions.shape)

print("\nFirst 5 Rows:")
display(investor_transactions.head())

print("\nInformation:")
investor_transactions.info()

print("\nMissing Values:")
print(investor_transactions.isnull().sum())

print("\nDuplicate Rows:")
print(investor_transactions.duplicated().sum())

print("\nStatistical Summary:")
display(investor_transactions.describe(include="all"))
# Out:
# ========== INVESTOR TRANSACTIONS ==========
# Shape:
# (32778, 13)
#
# First 5 Rows:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
# ...

# %%
print("========== PORTFOLIO HOLDINGS ==========")

print("Shape:")
print(portfolio_holdings.shape)

print("\nFirst 5 Rows:")
display(portfolio_holdings.head())

print("\nInformation:")
portfolio_holdings.info()

print("\nMissing Values:")
print(portfolio_holdings.isnull().sum())

print("\nDuplicate Rows:")
print(portfolio_holdings.duplicated().sum())

print("\nStatistical Summary:")
display(portfolio_holdings.describe(include="all"))
# Out:
# ========== PORTFOLIO HOLDINGS ==========
# Shape:
# (322, 8)
#
# First 5 Rows:
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
#
#    market_value_cr  current_price_inr portfolio_date
# 0           737.09            6011.08     2025-12-31
# 1            88.97            1074.65     2025-12-31
# 2           208.45            5964.59     2025-12-31
# 3           161.32            3748.82     2025-12-31
# 4           725.90            1321.45     2025-12-31
# Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# ...

# %%
print("========== BENCHMARK INDICES ==========")

print("Shape:")
print(benchmark_indices.shape)

print("\nFirst 5 Rows:")
display(benchmark_indices.head())

print("\nInformation:")
benchmark_indices.info()

print("\nMissing Values:")
print(benchmark_indices.isnull().sum())

print("\nDuplicate Rows:")
print(benchmark_indices.duplicated().sum())

print("\nStatistical Summary:")
display(benchmark_indices.describe(include="all"))
# Out:
# ========== BENCHMARK INDICES ==========
# Shape:
# (8050, 3)
#
# First 5 Rows:
#          date index_name  close_value
# 0  2022-01-03    NIFTY50     17492.79
# 1  2022-01-04    NIFTY50     17689.64
# 2  2022-01-05    NIFTY50     17835.05
# 3  2022-01-06    NIFTY50     17878.51
# 4  2022-01-07    NIFTY50     17759.15
# Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8050 entries, 0 to 8049
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         8050 non-null   object
#  1   index_name   8050 non-null   object
#  2   close_value  8050 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 188.8+ KB
#
# Missing Values:
# date           0
# index_name     0
# close_value    0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# Statistical Summary:
#               date index_name   close_value
# count         8050       8050   8050.000000
# unique        1150          7           NaN
# ...
